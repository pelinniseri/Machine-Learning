# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Import and read data

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
ss = pd.read_csv("gender_submission.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
ss.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
print("Training set shape: ", train.shape)
print("Test set shape: ", test.shape)
print("SS shape: ", ss.shape)
# Out:
# Training set shape:  (891, 12)
# Test set shape:  (418, 11)
# SS shape:  (418, 2)

# %% [raw]
# Survived: 0 = Did not survive, 1 = Survived
#
# Pclass: Ticket class where 1 = First class, 2 = Second class, 3 = Third class. This can also be seen as a proxy for socio-economic status.
#
# Sex: Male or female
#
# Age: Age in years, fractional if less than 1
#
# SibSp: Number of siblings or spouses aboard the titanic
#
# Parch: Number of parents or children aboard the titanic
#
# Ticket: Passenger ticket number
#
# Fare: Passenger fare
#
# Cabin: Cabin number
#
# Embarked: Point of embarkation where C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# # EDA

# %%
#Non-null count
train.info()
print('----------------------------------------------------------------------------------------')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# ----------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# ...

# %%
# Missing data in training set
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
missingno.matrix(train)
# Out:
# <AxesSubplot:>

# %%
# Missing data in test set 
missingno.matrix(test)
# Out:
# <AxesSubplot:>

# %%
#Statistics about train and test set
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
train['Sex'].value_counts(dropna = False)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# Mean of survival by sex

data_gender=train[['Sex', 'Survived']].groupby('Sex', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
data_gender
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
sns.barplot(x = 'Sex', y ='Survived', data = data_gender)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Gender')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Gender')

# %%
train['Pclass'].value_counts(dropna = False)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data_pclass=train[['Pclass', 'Survived']].groupby(['Pclass'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
data_pclass
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
sns.barplot(x = 'Pclass', y ='Survived', data = data_pclass)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Passenger Class')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Passenger Class')

# %%
# Survival by gender and passenger class

g = sns.catplot(x = 'Pclass', y = 'Survived', hue = 'Sex', data = train, kind = 'bar')
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Sex and Passenger Class')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Sex and Passenger Class')

# %%
train['Embarked'].value_counts(dropna = False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
data_embark=train[['Embarked', 'Survived']].groupby(['Embarked'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
data_embark
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %%
sns.barplot(x = 'Embarked', y ='Survived', data = data_embark)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Embarkation')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Embarkation')

# %%
g = sns.catplot(x = 'Pclass', y = 'Survived', hue = 'Embarked', data = train, kind = 'bar')
g.despine(left = True)

# %%
grid = sns.FacetGrid(train, row = 'Embarked', size = 2.0, aspect = 1.5)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', )
grid.add_legend()
# Out:
# C:\Users\pelin\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\pelin\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\pelin\anaconda3\lib\site-packages\seaborn\axisgrid.py:675: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid = sns.FacetGrid(train, row = 'Pclass', size = 2.0, aspect = 1.5)
grid.map(sns.pointplot, 'Embarked', 'Survived', 'Sex')
grid.add_legend()
# Out:
# C:\Users\pelin\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\pelin\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\pelin\anaconda3\lib\site-packages\seaborn\axisgrid.py:675: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#Detect and remove outliers in numerical variables

# %%
#Corr
sns.heatmap(train[['Survived', 'SibSp', 'Parch', 'Age', 'Fare']].corr(), annot = True, fmt = '.2f', cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
train['SibSp'].value_counts(dropna = False)
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
train[['SibSp', 'Survived']].groupby('SibSp', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
sns.barplot(x = 'SibSp', y ='Survived', data = train)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Siblings')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Siblings')

# %%
train['Parch'].value_counts(dropna = False)
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
train[['Parch', 'Survived']].groupby('Parch', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
sns.barplot(x = 'Parch', y ='Survived', data = train)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Parent/Child')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Parent/Child')

# %%
sns.distplot(train['Age'])
# Out:
# C:\Users\pelin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
g = sns.FacetGrid(train, col = 'Survived')
g.map(sns.distplot, 'Age')
# Out:
# C:\Users\pelin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\pelin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(train['Age'][train['Survived'] == 0], label = 'Did not survive',color='red')
sns.kdeplot(train['Age'][train['Survived'] == 1], label = 'Survived',color='black')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
train['Embarked'].isnull().sum()
# Out:
# 2

# %%
mode=train['Embarked'].mode()[0]
mode
# Out:
# 'S'

# %%
train['Embarked'].fillna(mode, inplace = True)

# %%
train['Embarked'].isnull().sum()
# Out:
# 0

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
mean = train['Age'].dropna().mean()
mean
# Out:
# 30.272590361445783

# %%
train['Age'].fillna(mean, inplace = True)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
del train['Cabin']

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
mean2 = train['Age'].dropna().mean()
mean2
# Out:
# 29.813039836112075

# %%
test['Age'].fillna(mean2, inplace = True)

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
del test['Cabin']

# %%
median = test['Fare'].dropna().median()
median
# Out:
# 14.4542

# %%
test['Fare'].fillna(median, inplace = True)

# %%
test.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
dummies1 = pd.get_dummies(train[['Sex']])
dummies1
# Out:
#      Sex_female  Sex_male
# 0             0         1
# 1             1         0
# 2             1         0
# 3             1         0
# 4             0         1
# ..          ...       ...
# 886           0         1
# 887           1         0
# 888           1         0
# 889           0         1
# 890           0         1
#
# [891 rows x 2 columns]

# %%
merged1 = pd.concat([train,dummies1],axis='columns')
merged1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male  22.00000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00000
# 2                               Heikkinen, Miss. Laina  female  26.00000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00000
# 4                             Allen, Mr. William Henry    male  35.00000
# ..                                                 ...     ...       ...
# ...

# %%
final1 = merged1.drop(['Sex'], axis='columns')
final1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name       Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.00000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.00000      1
# 2                               Heikkinen, Miss. Laina  26.00000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.00000      1
# 4                             Allen, Mr. William Henry  35.00000      0
# ..                                                 ...       ...    ...
# ...

# %%
dummies2 = pd.get_dummies(train[['Embarked']])
dummies2
# Out:
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 3 columns]

# %%
merged2 = pd.concat([final1,dummies2],axis='columns')
merged2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name       Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.00000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.00000      1
# 2                               Heikkinen, Miss. Laina  26.00000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.00000      1
# 4                             Allen, Mr. William Henry  35.00000      0
# ..                                                 ...       ...    ...
# ...

# %%
final2 = merged2.drop(['Embarked'], axis='columns')
final2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name       Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.00000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.00000      1
# 2                               Heikkinen, Miss. Laina  26.00000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.00000      1
# 4                             Allen, Mr. William Henry  35.00000      0
# ..                                                 ...       ...    ...
# ...

# %%
X_train = final2.drop(['Survived','Name','Ticket'], axis = 1)

X_train
# Out:
#      PassengerId  Pclass       Age  SibSp  Parch     Fare  Sex_female  \
# 0              1       3  22.00000      1      0   7.2500           0
# 1              2       1  38.00000      1      0  71.2833           1
# 2              3       3  26.00000      0      0   7.9250           1
# 3              4       1  35.00000      1      0  53.1000           1
# 4              5       3  35.00000      0      0   8.0500           0
# ..           ...     ...       ...    ...    ...      ...         ...
# 886          887       2  27.00000      0      0  13.0000           0
# 887          888       1  19.00000      0      0  30.0000           1
# 888          889       3  30.27259      1      2  23.4500           1
# 889          890       1  26.00000      0      0  30.0000           0
# 890          891       3  32.00000      0      0   7.7500           0
#
#      Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0           1           0           0           1
# ...

# %%
Y_train = train['Survived']
Y_train
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
Y_train.isnull().sum()
# Out:
# 0

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# C:\Users\pelin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("X_train shape: ", X_train.shape)
# Out:
# X_train shape:  (891, 11)

# %%
print("X_train shape: ", X_train.columns)
# Out:
# X_train shape:  Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_female',
#        'Sex_male', 'Embarked_C', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
dummies3 = pd.get_dummies(test[['Sex']])
dummies3
# Out:
#      Sex_female  Sex_male
# 0             0         1
# 1             1         0
# 2             0         1
# 3             0         1
# 4             1         0
# ..          ...       ...
# 413           0         1
# 414           1         0
# 415           0         1
# 416           0         1
# 417           0         1
#
# [418 rows x 2 columns]

# %%
merged3 = pd.concat([test,dummies3],axis='columns')
merged3
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
final3 = merged3.drop(['Sex'], axis='columns')
final3
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#           Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
dummies4 = pd.get_dummies(test[['Embarked']])
dummies4
# Out:
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           1           0
# 1             0           0           1
# 2             0           1           0
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 413           0           0           1
# 414           1           0           0
# 415           0           0           1
# 416           0           0           1
# 417           1           0           0
#
# [418 rows x 3 columns]

# %%
merged4 = pd.concat([final3,dummies4],axis='columns')
merged4
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#           Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
final4 = merged4.drop(['Embarked'], axis='columns')
final4
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#           Age  SibSp  Parch              Ticket      Fare  Sex_female  \
# ...

# %%
X_test = final4.drop(['Name','Ticket'], axis = 1)

X_test
# Out:
#      PassengerId  Pclass       Age  SibSp  Parch      Fare  Sex_female  \
# 0            892       3  34.50000      0      0    7.8292           0
# 1            893       3  47.00000      1      0    7.0000           1
# 2            894       2  62.00000      0      0    9.6875           0
# 3            895       3  27.00000      0      0    8.6625           0
# 4            896       3  22.00000      1      1   12.2875           1
# ..           ...     ...       ...    ...    ...       ...         ...
# 413         1305       3  29.81304      0      0    8.0500           0
# 414         1306       1  39.00000      0      0  108.9000           1
# 415         1307       3  38.50000      0      0    7.2500           0
# 416         1308       3  29.81304      0      0    8.0500           0
# 417         1309       3  29.81304      1      1   22.3583           0
#
#      Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0           1           0           1           0
# ...

# %%
Y_pred = lr.predict(X_test)

# %%
acc_log = lr.score(X_train, Y_train) 
acc_log
# Out:
# 0.7968574635241302

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = knn.score(X_train, Y_train) 
acc_knn
# Out:
# 0.7485970819304153

# %%
sgd = SGDClassifier()
sgd.fit(X_train, Y_train)
Y_pred = sgd.predict(X_test)
acc_sgd = sgd.score(X_train, Y_train)
acc_sgd
# Out:
# 0.6285072951739619

# %%
models = pd.DataFrame({'Model': [ 'KNN', 'Logistic Regression', 
                                  'Stochastic Gradient Decent', ],
                       'Score': [acc_knn, acc_log,
                                 acc_sgd]})

models.sort_values(by = 'Score', ascending = False, ignore_index = True)
# Out:
#                         Model     Score
# 0         Logistic Regression  0.796857
# 1                         KNN  0.748597
# 2  Stochastic Gradient Decent  0.628507

# %%
param_grid = [{'weights': ["uniform", "distance"], 'n_neighbors': [3, 4, 5]}]

knn_clf = KNeighborsClassifier()
grid_search = GridSearchCV(knn_clf, param_grid, cv=5,verbose=3)
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ....n_neighbors=3, weights=uniform;, score=0.620 total time=   0.0s
# [CV 2/5] END ....n_neighbors=3, weights=uniform;, score=0.399 total time=   0.0s
# [CV 3/5] END ....n_neighbors=3, weights=uniform;, score=0.466 total time=   0.0s
# [CV 4/5] END ....n_neighbors=3, weights=uniform;, score=0.483 total time=   0.0s
# [CV 5/5] END ....n_neighbors=3, weights=uniform;, score=0.680 total time=   0.0s
# [CV 1/5] END ...n_neighbors=3, weights=distance;, score=0.620 total time=   0.0s
# [CV 2/5] END ...n_neighbors=3, weights=distance;, score=0.399 total time=   0.0s
# [CV 3/5] END ...n_neighbors=3, weights=distance;, score=0.472 total time=   0.0s
# [CV 4/5] END ...n_neighbors=3, weights=distance;, score=0.483 total time=   0.0s
# [CV 5/5] END ...n_neighbors=3, weights=distance;, score=0.680 total time=   0.0s
# [CV 1/5] END ....n_neighbors=4, weights=uniform;, score=0.620 total time=   0.0s
# ...

# %%
print("Best parameters: ", grid_search.best_params_) 
print("Best estimator: ", grid_search.best_estimator_)
# Out:
# Best parameters:  {'n_neighbors': 4, 'weights': 'uniform'}
# Best estimator:  KNeighborsClassifier(n_neighbors=4)
